# %% [markdown]
# ### Задание 1
# Скачайте с сайта grouplens.org...movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
ratings = pd.read_csv('ratings.csv', usecols = ["movieId", "rating"])
movies = pd.read_csv('movies.csv', usecols = ["movieId", "title"])

# %%
#отбираем только с оценками=5, группируем по id фильма, считаем количество, получаем индекс(id) максимума count(rating),
#обращемся к нулевому значению Series, результат - в фильтр фильмов по id и выводим поле Название кина))
movies.query(f'movieId == {ratings.query("rating == 5").groupby(["movieId"]).count().idxmax()[0]}')['title']
# Out:
# 314    Shawshank Redemption, The (1994)
# Name: title, dtype: object

# %% [markdown]
# ### Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')

# %%
query_ = 'country in ["Estonia", "Latvia", "Lithuania"] and category in [4, 12, 21] and 2005<=year<=2010 and quantity>0'
power.query(query_)['quantity'].sum()
# Out:
# 240580.0

# %% [markdown]
# ### Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe. https://fortrader.org/quotes

# %%
url = 'https://fortrader.org/quotes'
tables = pd.read_html(url)
tables  # победить NaN ('Обновлено') я так и не смог(((
# Out:
# [                           Название   Цена  Изменение  Изменение(%)  Обновлено
#  0  EURRUB Курс евро к рублю сегодня  88.88       0.99          1.13        NaN
#  1       USDRUB Курс рубля к доллару  75.06       0.48          0.64        NaN,
#                                Название    Цена  Изменение  Изменение(%)  \
#  0       Нефть Brent Курс нефти сегодня   73.23      -0.11         -0.15
#  1          Нефть WTI Цены на нефть WTI   71.87      -0.23         -0.32
#  2  Природный газ Цена на природный газ    3.57      -0.01         -0.31
#  3                                 Кофе  149.40      -1.20         -0.80
#  4                             Кукуруза  545.60       2.00          0.37
#  5                                  Соя  361.80       1.90          0.53
#  6                               Хлопок   86.95      -0.68         -0.78
#
#     Обновлено
#  0        NaN
#  1        NaN
#  2        NaN
#  3        NaN
#  4        NaN
#  5        NaN
#  6        NaN  ,
#                             Название   Цена  Изменение  Изменение(%)  Обновлено
#  0       Золото Цена золота на бирже  1 817      13.00          1.00        NaN
#  1  Серебро Цена на серебро на бирже  26.15       0.02          0.06        NaN
#  2         Палладий Цена на Палладий  2 823     -27.00         -1.00        NaN
#  3           Платина Цены на платину  1 072     -12.00         -1.00        NaN
#  4           Медь Цена меди на бирже   4.24      -0.07         -1.55        NaN,
#                                          Название      Цена  Изменение  \
#  0                                  ВТБ Акции ВТБ  0.048800  -0.000600
#  1                         Газпром Акции газпрома    292.63      -4.76
#  2                            Лукойл Акции Лукойл   6 652.5     -129.5
#  3                        Роснефть Акции Роснефти    578.20      -2.05
#  4                       Сбербанк Акции Сбербанка    301.25      -2.81
#  5           Сургутнефтегаз Акции Сургутнефтегаза    35.915     -0.685
#  6                      Норникель Акции Норникель    24 552       -106
#  7                       Аэрофлот Акции Аерофлота     68.12      -0.22
#  8                    Северсталь Акции Северсталь  1 565.80     -24.20
#  9                    Транснефть Акции Транснефть   173 200     -1 200
#  10             Ростелеком Курс акций ростелекома    101.93      -0.11
#  11                      РУСАЛ Акции РУСАЛ (RUAL)    49.190     -0.415
#  12      Детский мир iDreamSky Technology Limited    143.04      -7.22
#  13             Петропавловск Акции Петропавловск     22.98      -0.49
#  14                    Алроса Акции АЛРОСА (ALRS)   127.350     +2.750
#  15                    Магнит Акции Магнит (MGNT)   5 290.5      -19.5
#  16                        НМЛК Акции НЛМК (NLMK)   226.580     -2.120
#  17                  М.видео Акции М.видео (MVID)    627.10      -7.30
#  18    Газпром нефть Акции "Газпром нефть" (SIBN)    441.00      -7.85
#  19                        НМТП Акции НМТП (NMTP)    6.9350    -0.0350
#  20            Полиметалл Акции Полиметалл (POLY)  1 648.10      +9.80
#  21        Полюс Золото Акции Полюс Золото (PLZL)  14 645.5     +120.0
#  22                  НОВАТЭК Акции НОВАТЭК (NVTK)  1 636.80      -3.20
#  23                РусГидро Акции РусГидро (HYDR)    0.8220    -0.0442
#  24                Татнефть Акции Татнефть (TATN)    520.80     -15.60
#  25        АФК Система Акции АФК "Система" (AFKS)    31.486     -0.184
#  26                                 МТС Акции МТС    320.75      -3.60
#  27                Башнефть Акции Башнефть (BANE)   1 455.5      -39.0
#  28                    Яндекс Акции Яндекс (YNDX)   5 270.8      -70.6
#  29  X5 Retail Group Акции X5 Retail Group (FIVE)  2 466.00     -47.00
#  30                  ФСК ЕЭС Акции ФСК ЕЭС (FEES)   0.22938   -0.00088
#  31                      Мечел Акции Мечел (MTLR)     75.12      +0.92
#  32                МосБиржа Акции МосБиржа (MOEX)    171.67      +0.15
#  33              Интер РАО Акции Интер РАО (IRAO)      4.69      -0.02
#  34              Mail.ru Акции Mail.ru (MAIL, ДР)  1 632.40     -16.60
#  35                        Киви Акции Киви (QIWI)     767.0       -6.5
#  36                  Лента Акции Лента (LNTA, ДР)    250.40      -0.80
#  37            Тинькофф Акции Тинькофф (TCSG, др)  6 630.60     -50.00
#  38                        Озон Акции Озон (Ozon)  4 111.00     -59.50
#
#      Изменение(%)  Обновлено
#  0      -1.214575        NaN
#  1      -1.600000        NaN
#  2      -1.900000        NaN
#  3      -0.350000        NaN
#  4      -0.920000        NaN
#  5      -1.872000        NaN
#  6      -0.000000        NaN
#  7      -0.320000        NaN
#  8      -1.520000        NaN
#  9      -1.000000        NaN
#  10     -0.110000        NaN
#  11     -0.837000        NaN
#  12     -4.810000        NaN
#  13     -2.090000        NaN
#  14      2.207000        NaN
#  15     -0.400000        NaN
#  16     -0.927000        NaN
#  17     -1.150000        NaN
#  18     -1.750000        NaN
#  19     -0.502200        NaN
#  20      0.600000        NaN
#  21      0.800000        NaN
#  22     -0.200000        NaN
#  23     -5.102700        NaN
#  24     -2.910000        NaN
#  25     -0.581000        NaN
#  26     -1.110000        NaN
#  27     -2.600000        NaN
#  28     -1.300000        NaN
#  29     -1.870000        NaN
#  30     -0.382180        NaN
#  31      1.240000        NaN
#  32      0.090000        NaN
#  33     -0.440000        NaN
#  34     -1.010000        NaN
#  35     -0.800000        NaN
#  36     -0.320000        NaN
#  37     -0.750000        NaN
#  38     -1.430000        NaN  ,
#                                 Название      Цена  Изменение  Изменение(%)  \
#  0           Google Акции Google (GOOGL)  2 480.00     -49.48         -1.96
#  1                   IBM Акции IBM (IBM)    138.00      -1.82         -1.30
#  2     Microsoft Акции Майкрософт (MSFT)    277.08      -2.85         -1.02
#  3              Apple Акции Apple (AAPL)    142.31      -2.26         -1.56
#  4                  Yandex Акции яндекса     70.29      -1.54         -2.14
#  5                   Toyota Акции Тойоты    172.00      -3.65         -2.08
#  6      Volkswagen Курс акций Volkswagen    200.30      -5.70         -2.77
#  7            Amazon Акции Amazon (AMZN)  3 640.15     -56.43         -1.53
#  8           Boeing Акции Boeing Company    225.75      -6.03         -2.60
#  9              Intel Акции Intel (INTC)     55.57      -0.39         -0.70
#  10            Coca-Cola Акции Coca-Cola     53.89      -0.43         -0.79
#  11         Netflix Акции Netflix (NFLX)    531.00      -4.96         -0.93
#  12            Pfizer Акции Pfizer (PFE)     38.91      -0.44         -1.12
#  13                        AMD Акции AMD     88.05      -2.49         -2.75
#  14  Walt Disney Акции Walt Disney (DIS)    170.10      -2.72         -1.57
#  15           NVIDIA Акции NVIDIA (NVDA)    793.00     -21.87         -2.68
#  16           PayPal Акции PayPal (PYPL)    290.00      -7.13         -2.40
#  17         Facebook Акции Facebook (FB)    347.00      -3.49         -1.00
#  18             Tesla Акции Тесла (TSLA)    630.35     -14.30         -2.22
#  19            Twiter Цена акций твитера     66.30      -2.46         -3.58
#  20    Hasbro Цена на акции Hasbro, Inc.     95.50      -1.43         -1.48
#  21                               Сименс    130.96      -2.72         -2.03
#  22                                 Qiwi     10.20      -0.10         -0.97
#  23     Mastercard Акции Mastercard (МА)    365.00      -8.92         -2.39
#  24         Moderna Акции Модерна (MRNA)    216.27      -5.63         -2.54
#  25        Макдональдс Акции Макдональдс    231.90      -2.73         -1.16
#  26                                 MSCI    497.12     -58.65        -10.55
#  27                             FIXPRICE      8.35      -0.28         -3.24
#  28                 Zoom Акции Zoom (ZM)    386.10      -7.81         -1.98
#  29     HeadHunter Акции HeadHunter (HH)     37.82      -7.30        -16.18
#
#      Обновлено
#  0         NaN
#  1         NaN
#  2         NaN
#  3         NaN
#  4         NaN
#  5         NaN
#  6         NaN
#  7         NaN
#  8         NaN
#  9         NaN
#  10        NaN
#  11        NaN
#  12        NaN
#  13        NaN
#  14        NaN
#  15        NaN
#  16        NaN
#  17        NaN
#  18        NaN
#  19        NaN
#  20        NaN
#  21        NaN
#  22        NaN
#  23        NaN
#  24        NaN
#  25        NaN
#  26        NaN
#  27        NaN
#  28        NaN
#  29        NaN  ,
#    Название      Цена  Изменение  Изменение(%)  Обновлено
#  0     FXIT  11 241.0  -118.0000       -1.0000        NaN
#  1     FXRU     969.9     4.4000        0.5000        NaN
#  2     FXDE   3 115.5   -34.5000       -1.1000        NaN
#  3     FXCN   3 655.0  -142.0000       -3.7000        NaN
#  4     FXGD    918.00    10.4000        1.1500        NaN
#  5     FXWO    1.8627    -0.0189       -1.0045        NaN,
#                                           Название       Цена Изменение  \
#  0         Индекс МосБиржи Индекс МосБиржи (IMOEX)    384 925    -3 850
#  1                    Индекс РТС Индекс РТС (RTSI)   1 618.90    -40.82
#  2                      Dow Jones Индекс Dow Jones  34 681.80      0.00
#  3                          S&P 500 Индекс S&P 500      4 293       -57
#  4                    Nasdaq 100 Индекс Nasdaq 100  14 810.50      0.00
#  5   Euro Stoxx 50 Индекс Euro Stoxx 50 (STOXX50E)    3 980.2     -99.4
#  6                            FTSE 100 Индекс FTSE   7 018.91   -132.11
#  7             Nikkei 225 Индекс Nikkei 225 (N225)     27 617      -685
#  8                Russell 2000 Индекс Russell 2000   2 252.85      0.00
#  9                              DAX30 Индекс DAX30   15 348.3    -317.7
#  10                           CAC 40 Индекс CAC 40    6 369.7    -158.4
#  11                         IBEX 35 Индекс IBEX 35    8 633.3    -209.1
#  12                         ASX 200 Индекс ASX 200    7 253.6     -88.0
#  13        Фьючерс РТС Курс фьючерса на индекс РТС    159 890    -2 300
#  14                                      USD INDEX      92.41     -0.29
#
#      Изменение(%)  Обновлено
#  0          -1.00        NaN
#  1          -2.46        NaN
#  2           0.00        NaN
#  3          -1.00        NaN
#  4           0.00        NaN
#  5          -2.40        NaN
#  6          -1.85        NaN
#  7          -2.00        NaN
#  8           0.00        NaN
#  9          -2.00        NaN
#  10         -2.40        NaN
#  11         -2.40        NaN
#  12         -1.20        NaN
#  13         -1.00        NaN
#  14         -0.31        NaN  ,
#                                             Название       Цена  Изменение  \
#  0                         EUR/USD Евро / Доллар США    1.18414    0.00486
#  1                         GBP/USD Фунт / Доллар США    1.37731   -0.00261
#  2                            USD/CHF Доллар / Франк    0.91700   -0.00867
#  3                         USD/JPY Доллар США / Иена  109.73500   -0.89900
#  4                             USD/CNH Доллар / Юань    6.49480    0.02210
#  5             USD/CAD Доллар США / Канадский доллар    1.25493    0.00672
#  6         AUD/USD Австралийский доллар / Доллар США    0.74305   -0.00526
#  7                              EUR/CHF Евро / Франк    1.08590   -0.00564
#  8   AUD/CAD Австралийский доллар / Канадский доллар    0.93248   -0.00161
#  9                      EUR/JPY Евро / Японская йена  129.95100   -0.52000
#  10                              EUR/GBP Евро / Фунт    0.85962    0.00507
#  11                              GBP/JPY Фунт / Йена  151.13700   -1.52400
#  12            NZDUSD New Zealand Dollar / US Dollar    0.69624   -0.00499
#
#      Изменение(%)  Обновлено
#  0        0.41212        NaN
#  1       -0.18914        NaN
#  2       -0.93662        NaN
#  3       -0.81300        NaN
#  4        0.34140        NaN
#  5        0.53837        NaN
#  6       -0.70292        NaN
#  7       -0.51670        NaN
#  8       -0.17236        NaN
#  9       -0.39900        NaN
#  10       0.59329        NaN
#  11      -0.99800        NaN
#  12      -0.71161        NaN  ,
#                                               Название       Цена  Изменение  \
#  0                               Bitcoin Курс биткоина  32 299.50  -1 552.10
#  1          Litecoin Курс лайткоин к доллару (LTC/USD)     128.58      -8.91
#  2   BitcoinCash Курс Биткоин кеш к доллару США (BC...     481.32     -27.76
#  3                                           Dash Dash     125.48      -9.26
#  4                                       Ripple Ripple    0.61384   -0.03858
#  5                                   Ethereum Ethereum   2 135.03    -180.79
#  6                                         Zcash (ZEC)     111.65      -6.33
#  7                                           NEO (NEO)      33.46      -3.47
#  8                                           EOS (EOS)     3.5775    -0.2381
#  9                                          TRON (TRX)   0.060457  -0.003909
#  10                                             Monero     204.16     -10.58
#  11                                               IOTA    0.80728   -0.07711
#  12                       ETC/USD эфириум классик, ETC     49.515     -3.245
#
#      Изменение(%)  Обновлено
#  0      -4.590000        NaN
#  1      -6.480000        NaN
#  2      -5.450000        NaN
#  3      -6.870000        NaN
#  4      -5.913370        NaN
#  5      -7.810000        NaN
#  6      -5.370000        NaN
#  7      -9.390000        NaN
#  8      -6.240200        NaN
#  9      -6.073082        NaN
#  10     -4.930000        NaN
#  11     -8.719000        NaN
#  12     -6.150000        NaN  ]
