# %%
import re

# %% [markdown]
# ### Задание 1
# Напишите функцию, которая принимает на вход строку и проверяет является ли она валидным транспортным номером (1 буква, 3 цифры, 2 буквы, 2-3 цифры). Обратите внимание, что не все буквы кириллического алфавита используются в транспортных номерах.
#
# Если номер валиден, то функция должна возвращать отдельно номер и регион.
#
# Примеры работы программы:
#
# car_id = 'А222BС96’
# Результат: Номер А222BС валиден. Регион: 96
#
# car_id = 'АБ22ВВ193’
# Результат: Номер не валиден

# %%
def check_auto_number(number_string):
    valid_number = re.fullmatch(r'(?i:[ABCEHKMOPTXYАВСЕНКМОРТХУ]{1}\d{3}[ABCEHKMOPTXYАВСЕНКМОРТХУ]{2}[17]?\d{2})', number_string)
    if valid_number:
        part1, part2 = re.findall(r'(\w{6}|\d{2}$|\d{3}$)', valid_number.string)
        print(f'Номер {part1} валиден. Регион: {part2}') 
    else:
        print('Номер не валиден')
check_auto_number('K528mР186')
# Out:
# Номер K528mР валиден. Регион: 186

# %% [markdown]
# ### Задание 2
# Напишите функцию, которая будет удалять все последовательные повторы слов из заданной строки при помощи регулярных выражений.
#
# Пример работы программы:
#
# some_string = ‘Напишите функцию функцию, которая будет будет будет будет удалять все все все все последовательные повторы слов из из из из заданной строки строки при помощи регулярных выражений’
#
# Результат: Напишите функцию, которая будет удалять все последовательные повторы слов из заданной строки при помощи регулярных выражений.

# %%
def remove_duplicate_words(source):
    return re.sub(r'(\w+)(\W(\1))+',r'\1', source)
 #   return re.sub(r'\b(\w+[\-\w+]*)\b(\s+(\1))+',r'\1', source)
# предположил, что может встретиться повтор дефисного слова и застрял... еще может встретиться комбинация "как как-то "
remove_duplicate_words('Напишите Напишите функцию функцию, которая как как-то будет будет или не будет будет будет удалять все все-все все а а а может и не все все последовательные повторы слов из из из из заданной строки строки при помощи регулярных выражений выражений')
# Out:
# 'Напишите функцию, которая как-то будет или не будет удалять все а может и не все последовательные повторы слов из заданной строки при помощи регулярных выражений'

# %% [markdown]
# ### Задание 3
# Напишите функцию, которая будет возвращать акроним по переданной в нее строке со словами.
#
# Примеры работы программы:
#
# some_words = 'Информационные технологии’
# Результат: ИТ
#
# some_words = 'Near Field Communication’
# Результат: NFC

# %%
def acronym(source):
    return re.sub(r'\b(\w)\w+\b\s*', r'\1', source).upper()
acronym('Near Field Communication')
# Out:
# 'NFC'

# %% [markdown]
# ### Задание 4
# Напишите функцию, которая будет принимать на вход список email-адресов и выводить их распределение по доменным зонам.
#
# Пример работы программы:
#
# emails = [‘test@gmail.com, xyz@test.in, test@ya.ru, xyz@mail.ru, xyz@ya.ru’, xyz@gmail.com]
#
# Результат:
#
# gmail.com: 2
# test.in: 1
# ya.ru: 2
# mail.ru: 1

# %%
e_mails = ['test@gmail.com', 'xyz@test.in', 'test@ya.ru', 'xyz@mail.ru', 'xyz@ya.ru', 'xyz@gmail.com']
def domains_count(emails):
    domains = re.findall(fr'@(\w+.\w+)', str(emails))
    dict_ = {domain: str(domains.count(domain)) for domain in domains}
    
    return ' '.join(['%s: %s' % key for key in dict_.items()])
#    return ' '.join([''.join([key, ': ', value]) for key, value in dict_.items()])
#    return ' '.join([key + ': ' + value for key, value in dict_.items()])
print(domains_count(e_mails))
# Out:
# gmail.com: 2 test.in: 1 ya.ru: 2 mail.ru: 1

# %% [markdown]
# ### Задание 5 (необязательное)
#
# Напишите функцию, которая будет подсчитывать сколько слов начинается на гласные, а сколько на согласные буквы в тексте (текст может быть написан как с использованием букв кириллицы, так и латиницы).
#
# Пример работы программы:
#
# some_text = ‘Эталонной реализацией Python является интерпретатор CPython, поддерживающий большинство активно используемых платформ. Он распространяется под свободной лицензией Python Software Foundation License, позволяющей использовать его без ограничений в любых приложениях, включая проприетарные.’
#
# Результат:
#
# Слов на гласные буквы: 9
# Слов на согласные буквы: 21

# %%
some_text = 'Эталонной реализацией Python является интерпретатор CPython, поддерживающий большинство активно используемых платформ. Он распространяется под свободной лицензией Python Software Foundation License, позволяющей использовать его без ограничений в любых приложениях, включая проприетарные.'

def start_with_vow_cons_letters(text):
    vow_pattern = re.compile(r'\b(?i:([AEIOUYАЕЁИОУЫЭЮЯ]))\w*\b')
    cons_pattern = re.compile(r'\b(?i:([BCDFGHJKLMNPQRSTVWXZБВГДЖЗЙКЛМНПРСТФХЦЧШЩЪЬ]))\w*\b')
    return len(vow_pattern.findall(text)), len(cons_pattern.findall(text))
vow, cons = start_with_vow_cons_letters(some_text)
print(f'Слов на гласные буквы: {vow} Слов на согласные буквы: {cons}')
# Out:
# Слов на гласные буквы: 9 Слов на согласные буквы: 21

# %% [markdown]
# ### Задание 6 (необязательное)
#
# Напишите функцию, которая будет проверять номер сотового телефона на валидность, если он валиден, то переводить его в формат:
# +7-xxx-xxx-xx-xx
# Постарайтесь предусмотреть как можно больше адекватных форматов изначального ввода номера. Примеры работы программы:
#
# phone = '+7 955 555-55-55’
# Результат: +7-950-555-55-55
#
# phone = '8(955)555-55-55’
# Результат: +7-950-555-55-55
#
# phone = '+7 955 555 55 55’
# Результат: +7-950-555-55-55
#
# phone = '7(955) 555-55-55’
# Результат: +7-950-555-55-55
#
# phone = '423-555-55-5555’
# Результат: Номер не валиден
#
# phone = '123-456-789’
# Результат: Номер не валиден

# %%
def format_phone_number(phone):
    pattern = r'^(\+?7|8)(\s?(\d{3})|(\s?)\((\d{3})\)(\4?|\s?)|((\s|\-)(\d{3})(\8|\-)))(\d{3})(\6?\10?|\-?)(\d{2})\12(\d{2})$'
    formatted_number, valid = re.subn(pattern, r'+7-\3\5\9-\11-\13-\14', phone)
    if valid!=0:
        return formatted_number
    else:
        return 'Номер не валиден'

phone_numbers=[
    '+7 955 555-55-55',
    '8(955)555-55-55',
    '+7 955 555 55 55',
    '7(955) 555-55-55',
    '423-555-55-5555',
    '123-456-789',
    '+7(987)654 32 10',
    '+7(987)654-32-10',
    '+7(987 )6543210',
    '+7(987) 6543210',
    '7 (987) 654 32 10',
    '+7(987)654-32-10',
    '8-987-654 32 10',
    '+7 987-654-32-10',
    '+7-987 654-32-10',
    '+7-9876543210',
    '7 987 654-32-10',
    '+7(987)654-32 10',
    '+7(987)654 32-10',    
    '+7(987)65432-10',
    '+7 (987)6543210'
]

for num in phone_numbers:
    print(f'phone={num} Результат: {format_phone_number(num)}')
# Out:
# phone=+7 955 555-55-55 Результат: +7-955-555-55-55
# phone=8(955)555-55-55 Результат: +7-955-555-55-55
# phone=+7 955 555 55 55 Результат: +7-955-555-55-55
# phone=7(955) 555-55-55 Результат: +7-955-555-55-55
# phone=423-555-55-5555 Результат: Номер не валиден
# phone=123-456-789 Результат: Номер не валиден
# phone=+7(987)654 32 10 Результат: Номер не валиден
# phone=+7(987)654-32-10 Результат: +7-987-654-32-10
# phone=+7(987 )6543210 Результат: Номер не валиден
# phone=+7(987) 6543210 Результат: +7-987-654-32-10
# phone=7 (987) 654 32 10 Результат: +7-987-654-32-10
# phone=+7(987)654-32-10 Результат: +7-987-654-32-10
# phone=8-987-654 32 10 Результат: Номер не валиден
# phone=+7 987-654-32-10 Результат: +7-987-654-32-10
# phone=+7-987 654-32-10 Результат: Номер не валиден
# phone=+7-9876543210 Результат: Номер не валиден
# phone=7 987 654-32-10 Результат: +7-987-654-32-10
# phone=+7(987)654-32 10 Результат: Номер не валиден
# phone=+7(987)654 32-10 Результат: Номер не валиден
# ...
